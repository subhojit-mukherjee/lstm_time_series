# %% [markdown]
# # LSTM for Time-Series
# ### ADAM, Batch size 256, Sequence Length 50
# This notebook is the resultant of three different cross validation experiments

# %% [markdown]
# Following code shows how to train a LSTM based RNN with Time-Series data and extrapolates for future patterns. Keras with Tensorflow-GPU backend has been used

# %% [markdown]
# #### Header

# %% [markdown]
# #### General libs

# %%
import os
import time
import pickle
import warnings
from datetime import datetime

# %% [markdown]
# #### Data structures

# %%
import numpy as np
import pandas as pd
from numpy import newaxis

# %% [markdown]
# #### Visualization

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# #### ML libs

# %%
from sklearn import metrics
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# #### Deep learning libs

# %%
import tensorflow as tf
from keras.layers.core import Dense, Activation, Dropout
from keras.layers import LeakyReLU
from keras.layers.recurrent import LSTM
from keras.models import Sequential
from keras.callbacks import TensorBoard, ReduceLROnPlateau, Callback, ModelCheckpoint
from keras.optimizers import Adam

# %% [markdown]
# #### Devices avaliable for Tensorflow backend
# Check the last line with __'physical_device_desc'__ flag to confirm the default device. If GPU is available, it should show the specifications for the same

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 12789415133873064896
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 1492117094
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 5834906909048701692
# physical_device_desc: "device: 0, name: GeForce 940M, pci bus id: 0000:01:00.0, compute capability: 5.0"
# ]

# %% [markdown]
# #### Hide warnings

# %%
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' #Hide messy TensorFlow warnings
warnings.filterwarnings("ignore") #Hide messy Numpy warnings

# %% [markdown]
# #### Callback class to clear the state at the end of epoch

# %%
class Model_state_reset(Callback):
    def on_epoch_end(self, epoch, logs={}):
        self.model.reset_states()

# %% [markdown]
# #### Data Loader
# This module will load the data, transform it to supervised format and return it with train test split

# %%
def configure_data(seq_len, data, normalise_window):
    sequence_length = seq_len + 1
    result = []
    for index in range(len(data) - sequence_length):
        result.append(data[index: index + sequence_length])
    
    if normalise_window:
        result = normalise_windows(result)

    result = np.array(result)

    row = round(0.9 * result.shape[0])
    train = result[:int(row), :]
    #np.random.shuffle(train)
    x_train = train[:, :-1]
    y_train = train[:, -1]
    x_test = result[int(row):, :-1]
    y_test = result[int(row):, -1]

    x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
    x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))  

    return [x_train, y_train, x_test, y_test]

# %% [markdown]
# #### Data normalisers
# This method will create 1-lag difference to make the data 'stationary'

# %%
def difference(dataset, interval=1):
    diff = list()
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return diff

# %% [markdown]
# #### Model builder
# 4 layers are there
# * 1 Input = Contains feature of sequence length, in this use case
# * 1st hidden = maps sequnce length numbered features to hidden unit feature space
# * 2nd hidden = maps intermediate features from 1st hidden unit to current hidden unit feature space
# * 1 output = Fully connected to work with linear activation for regression type action
#
# __Key points__
# * Check the dimensions
# * Intermediate layers(except the second last) should have __return_sequences__ flag as true. Because it returns the time step information
# * __stateful__ flag should be set to true if information retaining is required in betwen mini-batches. Although state/information/weights should be cleared after epoch by callbacks, otherwise it can suffer vanishing gradients
# * Droput layer should be added after activation, specially if relu is used. Prediction net should not contain dropouts.

# %%
 def build_model(layers, batch_size, predict = False):
    model = Sequential()

    model.add(LSTM(
        batch_input_shape=(batch_size, layers[1], layers[0]),
        output_dim=layers[1],
        return_sequences=True,stateful=True))
    if not predict:
        model.add(Dropout(0.2))

    model.add(LSTM(
        layers[2],
        return_sequences=True,stateful=True))
    lrelu = LeakyReLU(alpha=0.01)
    model.add(lrelu)
    if not predict:
        model.add(Dropout(0.2))
    
    model.add(LSTM(
        layers[3],
        return_sequences=False,stateful=True))
    lrelu = LeakyReLU(alpha=0.01)
    model.add(lrelu)
    if not predict:
        model.add(Dropout(0.2))

    model.add(Dense(
        output_dim=layers[4]))
    model.add(Activation("linear"))

    adam = Adam(lr=0.01, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
    
    start = time.time()
    model.compile(loss="mse", optimizer = adam)
    print("> Compilation Time : ", time.time() - start)
    return model

# %% [markdown]
# #### Predict each timestep given the last sequence of true data, in effect only predicting 1 step ahead each time

# %%
# def predict_point_by_point(model, data, batch_size):
#     predicted = model.predict(data,batch_size = batch_size)
#     predicted = np.reshape(predicted, (predicted.size,))
#     return predicted

# %%
def predict_point_by_point(model, data):
    predicted = model.predict(data, batch_size=1)
    predicted = np.reshape(predicted, (predicted.size,))
    return predicted

# %% [markdown]
# #### Multi point prediction

# %%
def predict_sequence_full(model, data, window_size):
    #Shift the window by 1 new prediction each time, re-run predictions on new window
    curr_frame = data[0]
    predicted = []
    for i in range(len(data)):
        predicted.append(model.predict(curr_frame[newaxis,:,:])[0,0])
        curr_frame = curr_frame[1:]
        curr_frame = np.insert(curr_frame, [window_size-1], predicted[-1], axis=0)
    return predicted

def predict_sequences_multiple(model, data, window_size, prediction_len):
    #Predict sequence of 50 steps before shifting prediction run forward by 50 steps
    prediction_seqs = []
    for i in range(int(len(data)/prediction_len)):
        curr_frame = data[i*prediction_len]
        predicted = []
        for j in range(prediction_len):
            predicted.append(model.predict(curr_frame[newaxis,:,:])[0,0])
            curr_frame = curr_frame[1:]
            curr_frame = np.insert(curr_frame, [window_size-1], predicted[-1], axis=0)
        prediction_seqs.append(predicted)
    return prediction_seqs

# %% [markdown]
# #### Single point plotting

# %%
def plot_results(predicted_data, true_data):
    fig = plt.figure(facecolor='white', figsize=[15,10])
    ax = fig.add_subplot(111)
    ax.plot(true_data, label='True Data')
    plt.plot(predicted_data, label='Prediction')
    plt.legend()
    plt.show()

# %% [markdown]
# #### Multiple points prediction plotting

# %%
def plot_results_multiple(predicted_data, true_data, prediction_len):
    fig = plt.figure(facecolor='white', figsize=[15,10])
    ax = fig.add_subplot(111)
    ax.plot(true_data, label='True Data')
    #Pad the list of predictions to shift it in the graph to it's correct start
    for i, data in enumerate(predicted_data):
        padding = [None for p in range(i * prediction_len)]
        plt.plot(padding + data, label='Prediction')
        plt.legend()
    plt.show()

# %% [markdown]
# #### Input size calculator as per batch

# %%
def size_calc(n,m):
    return n - n %m

# %% [markdown]
# #### Variable and constant initialisation

# %%
global_start_time = time.time()
epochs  = 100
seq_len = 50
batch_size = 256
layer_arch = [1, 50, 100, 50, 1]

print('> Loading data... ')
# Out:
# > Loading data...

# %% [markdown]
# #### Data loading

# %%
with open('ts1.pkl', 'rb') as handle:
    collected_op_type_one = pickle.load(handle)

# %% [markdown]
# #### Converting to data frame

# %%
ts1_df = pd.DataFrame(collected_op_type_one)

# %% [markdown]
# #### Converting the values to numeric

# %%
ts1_df['values'] = ts1_df['values'].apply(lambda a:int(a))

# %%
len(ts1_df['timestamp'].unique())
# Out:
# 143843

# %% [markdown]
# #### Total number of timestamps

# %%
ts1_df.count()
# Out:
# timestamp    143938
# values       143938
# dtype: int64

# %% [markdown]
# #### Converting to 1-D array

# %%
input_array = np.array(ts1_df['values'])

# %% [markdown]
# #### Taking differences of consecutive time stamps.

# %%
input_array = difference(dataset= input_array)

# %% [markdown]
# #### Converting list to numpy arrays

# %%
input_array = np.array(input_array)

# %% [markdown]
# #### Reshaping to be in (N,1)

# %%
input_array = np.reshape(input_array,(-1,1))

# %%
input_array.shape
# Out:
# (143937, 1)

# %% [markdown]
# #### Scale the data to be in Minimum and Maximum ranges

# %%
scale = MinMaxScaler(feature_range=(-1,1))

# %%
input_array = scale.fit_transform(input_array)

# %% [markdown]
# #### Get Custom train and test split, in supervised learning format

# %%
X_train, y_train, X_test, y_test = configure_data(seq_len, input_array, False)

# %%
print('X_Train:',len(X_train), 'Y_Train:',len(y_train))
print('X_Test:',len(X_test),'Y_test:',len(y_test))
# Out:
# X_Train: 129497 Y_Train: 129497
# X_Test: 14389 Y_test: 14389

# %%
print('X_Train shape:',X_train.shape, 'Y_Train shape:',y_train.shape)
print('X_Test shape:', X_test.shape,'Y_test shape:', y_test.shape)
# Out:
# X_Train shape: (129497, 50, 1) Y_Train shape: (129497, 1)
# X_Test shape: (14389, 50, 1) Y_test shape: (14389, 1)

# %% [markdown]
# #### input data size calculation

# %%
required_input_size = size_calc(len(X_train), batch_size)

# %%
len(X_train[:required_input_size])
# Out:
# 129280

# %%
required_validation_size = size_calc(len(X_test), batch_size)

# %% [markdown]
# ### Callbacks definition

# %%
date_stamp = datetime.now().strftime("%Y_%m_%d")

# %% [markdown]
# #### Reset the model states after epoch

# %%
reset_state = Model_state_reset()

# %% [markdown]
# #### Model check point for best model only to pin point the best one in all epochs

# %%
checkpoint = ModelCheckpoint(os.getcwd() + "\\checkpoint\\" + date_stamp + "_weights_adam_"+ str(batch_size)+ '_' 
                             + str(seq_len)+ ".hdf5", monitor='val_loss', 
                             verbose=1, save_best_only=True, save_weights_only = True, mode='min')

# %% [markdown]
# #### Tensorboard callback

# %%
tensorboard = TensorBoard(log_dir = os.getcwd() + '\\' + 'logs_cv_result\\' + date_stamp, )

# %% [markdown]
# #### Reduce learning rate if validation set loss does not improve for 5 epochs, to avoid plateau

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.9, patience=5, min_lr=0.000001, verbose=1)

# %% [markdown]
# #### Build the model

# %%
train_start_time = time.time()

# %%
model = build_model(layers= layer_arch, batch_size=batch_size, set_weights=False)
model.summary()

print("\n\n\n")



history = model.fit(X_train[:required_input_size], y_train[:required_input_size], batch_size=batch_size, 
                nb_epoch= epochs, 
                validation_data=(X_test[:required_validation_size], y_test[:required_validation_size]), 
                verbose=1, 
                shuffle = False, callbacks=[tensorboard, reduce_lr, checkpoint, reset_state])

print("\n\n End of learning with")
# Out:
# > Compilation Time :  0.015986919403076172
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (256, 50, 50)             10400
# _________________________________________________________________
# dropout_1 (Dropout)          (256, 50, 50)             0
# _________________________________________________________________
# lstm_2 (LSTM)                (256, 50, 100)            60400
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (256, 50, 100)            0
# _________________________________________________________________
# dropout_2 (Dropout)          (256, 50, 100)            0
# _________________________________________________________________
# lstm_3 (LSTM)                (256, 50)                 30200
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (256, 50)                 0
# _________________________________________________________________
# dropout_3 (Dropout)          (256, 50)                 0
# _________________________________________________________________
# dense_1 (Dense)              (256, 1)                  51
# _________________________________________________________________
# activation_1 (Activation)    (256, 1)                  0
# =================================================================
# Total params: 101,051
# Trainable params: 101,051
# Non-trainable params: 0
# _________________________________________________________________
#
#
#
#
# Train on 129280 samples, validate on 14336 samples
# Epoch 1/100
# 129280/129280 [==============================] - 241s 2ms/step - loss: 0.0013 - val_loss: 0.0015
#
# Epoch 00001: val_loss improved from inf to 0.00147, saving model to F:\Repository\temp\checkpoint\2018_08_08_weights_adam_256_50.hdf5
# Epoch 2/100
# 129280/129280 [==============================] - 240s 2ms/step - loss: 0.0012 - val_loss: 0.0014
#
# Epoch 00002: val_loss improved from 0.00147 to 0.00139, saving model to F:\Repository\temp\checkpoint\2018_08_08_weights_adam_256_50.hdf5
# Epoch 3/100
# 129280/129280 [==============================] - 241s 2ms/step - loss: 0.0011 - val_loss: 0.0013
#
# Epoch 00003: val_loss improved from 0.00139 to 0.00129, saving model to F:\Repository\temp\checkpoint\2018_08_08_weights_adam_256_50.hdf5
# Epoch 4/100
# 129280/129280 [==============================] - 239s 2ms/step - loss: 0.0012 - val_loss: 0.0014
#
# Epoch 00004: val_loss did not improve from 0.00129
# Epoch 5/100
# 129280/129280 [==============================] - 239s 2ms/step - loss: 0.0012 - val_loss: 0.0014
#
# Epoch 00005: val_loss did not improve from 0.00129
# Epoch 6/100
# 129280/129280 [==============================] - 238s 2ms/step - loss: 0.0012 - val_loss: 0.0013
#
# Epoch 00006: val_loss did not improve from 0.00129
# Epoch 7/100
# 129280/129280 [==============================] - 238s 2ms/step - loss: 0.0011 - val_loss: 0.0013
#
# Epoch 00007: val_loss improved from 0.00129 to 0.00126, saving model to F:\Repository\temp\checkpoint\2018_08_08_weights_adam_256_50.hdf5
# Epoch 8/100
# 129280/129280 [==============================] - 239s 2ms/step - loss: 0.0011 - val_loss: 0.0013
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.008999999798834325.
#
# Epoch 00008: val_loss did not improve from 0.00126
# Epoch 9/100
# 129280/129280 [==============================] - 239s 2ms/step - loss: 0.0010 - val_loss: 0.0012
#
# Epoch 00009: val_loss improved from 0.00126 to 0.00123, saving model to F:\Repository\temp\checkpoint\2018_08_08_weights_adam_256_50.hdf5
# Epoch 10/100
# 129280/129280 [==============================] - 235s 2ms/step - loss: 0.0011 - val_loss: 0.0013
#
# Epoch 00010: val_loss did not improve from 0.00123
# Epoch 11/100
# 129280/129280 [==============================] - 236s 2ms/step - loss: 0.0011 - val_loss: 0.0013
#
# Epoch 00011: val_loss did not improve from 0.00123
# Epoch 12/100
# 129280/129280 [==============================] - 235s 2ms/step - loss: 0.0011 - val_loss: 0.0013
#
# Epoch 00012: val_loss did not improve from 0.00123
# Epoch 13/100
# 129280/129280 [==============================] - 238s 2ms/step - loss: 0.0010 - val_loss: 0.0012
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.008099999651312828.
#
# Epoch 00013: val_loss improved from 0.00123 to 0.00122, saving model to F:\Repository\temp\checkpoint\2018_08_08_weights_adam_256_50.hdf5
# Epoch 14/100
# 129280/129280 [==============================] - 235s 2ms/step - loss: 0.0010 - val_loss: 0.0012
#
# Epoch 00014: val_loss did not improve from 0.00122
# Epoch 15/100
# 129280/129280 [==============================] - 235s 2ms/step - loss: 0.0010 - val_loss: 0.0013
#
# Epoch 00015: val_loss did not improve from 0.00122
# Epoch 16/100
# 129280/129280 [==============================] - 222s 2ms/step - loss: 0.0010 - val_loss: 0.0015
#
# Epoch 00016: val_loss did not improve from 0.00122
# Epoch 17/100
# 129280/129280 [==============================] - 220s 2ms/step - loss: 0.0010 - val_loss: 0.0012
#
# Epoch 00017: val_loss did not improve from 0.00122
# Epoch 18/100
# 129280/129280 [==============================] - 220s 2ms/step - loss: 0.0011 - val_loss: 0.0012
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.007289999350905419.
#
# Epoch 00018: val_loss did not improve from 0.00122
# Epoch 19/100
# 129280/129280 [==============================] - 221s 2ms/step - loss: 0.0010 - val_loss: 0.0012
#
# Epoch 00019: val_loss improved from 0.00122 to 0.00120, saving model to F:\Repository\temp\checkpoint\2018_08_08_weights_adam_256_50.hdf5
# Epoch 20/100
# 129280/129280 [==============================] - 221s 2ms/step - loss: 0.0011 - val_loss: 0.0013
#
# Epoch 00020: val_loss did not improve from 0.00120
# Epoch 21/100
# 129280/129280 [==============================] - 221s 2ms/step - loss: 0.0010 - val_loss: 0.0012
#
# Epoch 00021: val_loss did not improve from 0.00120
# Epoch 22/100
# 129280/129280 [==============================] - 220s 2ms/step - loss: 0.0010 - val_loss: 0.0015
#
# Epoch 00022: val_loss did not improve from 0.00120
# Epoch 23/100
# 129280/129280 [==============================] - 220s 2ms/step - loss: 0.0010 - val_loss: 0.0012
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.006560999248176813.
#
# Epoch 00023: val_loss did not improve from 0.00120
# Epoch 24/100
# 129280/129280 [==============================] - 225s 2ms/step - loss: 0.0010 - val_loss: 0.0013
#
# Epoch 00024: val_loss did not improve from 0.00120
# Epoch 25/100
# 129280/129280 [==============================] - 221s 2ms/step - loss: 9.9165e-04 - val_loss: 0.0012
#
# Epoch 00025: val_loss did not improve from 0.00120
# Epoch 26/100
# 129280/129280 [==============================] - 221s 2ms/step - loss: 0.0010 - val_loss: 0.0014
#
# Epoch 00026: val_loss did not improve from 0.00120
# Epoch 27/100
# 129280/129280 [==============================] - 221s 2ms/step - loss: 0.0010 - val_loss: 0.0012
#
# Epoch 00027: val_loss improved from 0.00120 to 0.00119, saving model to F:\Repository\temp\checkpoint\2018_08_08_weights_adam_256_50.hdf5
# Epoch 28/100
# 129280/129280 [==============================] - 220s 2ms/step - loss: 9.8100e-04 - val_loss: 0.0012
#
# Epoch 00028: val_loss did not improve from 0.00119
# Epoch 29/100
# 129280/129280 [==============================] - 220s 2ms/step - loss: 9.8582e-04 - val_loss: 0.0012
#
# Epoch 00029: val_loss did not improve from 0.00119
# Epoch 30/100
# 129280/129280 [==============================] - 220s 2ms/step - loss: 9.7768e-04 - val_loss: 0.0012
#
# Epoch 00030: val_loss did not improve from 0.00119
# Epoch 31/100
# 129280/129280 [==============================] - 220s 2ms/step - loss: 9.7152e-04 - val_loss: 0.0012
#
# Epoch 00031: val_loss improved from 0.00119 to 0.00118, saving model to F:\Repository\temp\checkpoint\2018_08_08_weights_adam_256_50.hdf5
# Epoch 32/100
# 129280/129280 [==============================] - 220s 2ms/step - loss: 9.7855e-04 - val_loss: 0.0012
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.005904899490997195.
#
# Epoch 00032: val_loss did not improve from 0.00118
# Epoch 33/100
# 129280/129280 [==============================] - 221s 2ms/step - loss: 9.6682e-04 - val_loss: 0.0012
#
# Epoch 00033: val_loss did not improve from 0.00118
# Epoch 34/100
# 129280/129280 [==============================] - 221s 2ms/step - loss: 9.7217e-04 - val_loss: 0.0013
#
# Epoch 00034: val_loss did not improve from 0.00118
# Epoch 35/100
# 129280/129280 [==============================] - 221s 2ms/step - loss: 9.7692e-04 - val_loss: 0.0012
#
# Epoch 00035: val_loss did not improve from 0.00118
# Epoch 36/100
# 129280/129280 [==============================] - 221s 2ms/step - loss: 9.6706e-04 - val_loss: 0.0012
#
# Epoch 00036: val_loss did not improve from 0.00118
# Epoch 37/100
# 129280/129280 [==============================] - 220s 2ms/step - loss: 9.6001e-04 - val_loss: 0.0012
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 0.00531440949998796.
#
# Epoch 00037: val_loss improved from 0.00118 to 0.00118, saving model to F:\Repository\temp\checkpoint\2018_08_08_weights_adam_256_50.hdf5
# Epoch 38/100
# 129280/129280 [==============================] - 220s 2ms/step - loss: 9.6099e-04 - val_loss: 0.0012
#
# Epoch 00038: val_loss did not improve from 0.00118
# Epoch 39/100
# 129280/129280 [==============================] - 220s 2ms/step - loss: 9.5415e-04 - val_loss: 0.0012
#
# Epoch 00039: val_loss did not improve from 0.00118
# Epoch 40/100
# 129280/129280 [==============================] - 220s 2ms/step - loss: 9.5213e-04 - val_loss: 0.0013
#
# Epoch 00040: val_loss did not improve from 0.00118
# Epoch 41/100
# 129280/129280 [==============================] - 221s 2ms/step - loss: 9.5543e-04 - val_loss: 0.0012
#
# Epoch 00041: val_loss improved from 0.00118 to 0.00118, saving model to F:\Repository\temp\checkpoint\2018_08_08_weights_adam_256_50.hdf5
# Epoch 42/100
# 129280/129280 [==============================] - 220s 2ms/step - loss: 9.4468e-04 - val_loss: 0.0012
#
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 0.004782968759536744.
#
# Epoch 00042: val_loss did not improve from 0.00118
# Epoch 43/100
# 129280/129280 [==============================] - 220s 2ms/step - loss: 9.4382e-04 - val_loss: 0.0012
#
# Epoch 00043: val_loss improved from 0.00118 to 0.00116, saving model to F:\Repository\temp\checkpoint\2018_08_08_weights_adam_256_50.hdf5
# Epoch 44/100
# 129280/129280 [==============================] - 220s 2ms/step - loss: 9.4056e-04 - val_loss: 0.0012
#
# Epoch 00044: val_loss did not improve from 0.00116
# Epoch 45/100
# 129280/129280 [==============================] - 220s 2ms/step - loss: 9.3636e-04 - val_loss: 0.0012
#
# Epoch 00045: val_loss did not improve from 0.00116
# Epoch 46/100
# 129280/129280 [==============================] - 220s 2ms/step - loss: 9.4351e-04 - val_loss: 0.0012
#
# Epoch 00046: val_loss did not improve from 0.00116
# Epoch 47/100
# 129280/129280 [==============================] - 220s 2ms/step - loss: 9.4481e-04 - val_loss: 0.0012
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 0.0043046717997640375.
#
# Epoch 00047: val_loss did not improve from 0.00116
# Epoch 48/100
# 129280/129280 [==============================] - 220s 2ms/step - loss: 9.3412e-04 - val_loss: 0.0012
#
# Epoch 00048: val_loss improved from 0.00116 to 0.00116, saving model to F:\Repository\temp\checkpoint\2018_08_08_weights_adam_256_50.hdf5
# Epoch 49/100
# 129280/129280 [==============================] - 221s 2ms/step - loss: 9.2685e-04 - val_loss: 0.0011
#
# Epoch 00049: val_loss improved from 0.00116 to 0.00115, saving model to F:\Repository\temp\checkpoint\2018_08_08_weights_adam_256_50.hdf5
# Epoch 50/100
# 129280/129280 [==============================] - 220s 2ms/step - loss: 9.2335e-04 - val_loss: 0.0012
#
# Epoch 00050: val_loss did not improve from 0.00115
# Epoch 51/100
# 129280/129280 [==============================] - 220s 2ms/step - loss: 9.2240e-04 - val_loss: 0.0012
#
# Epoch 00051: val_loss did not improve from 0.00115
# Epoch 52/100
# 129280/129280 [==============================] - 220s 2ms/step - loss: 9.2505e-04 - val_loss: 0.0012
#
# Epoch 00052: ReduceLROnPlateau reducing learning rate to 0.0038742044940590858.
#
# Epoch 00052: val_loss did not improve from 0.00115
# Epoch 53/100
# 129280/129280 [==============================] - 221s 2ms/step - loss: 9.2814e-04 - val_loss: 0.0012
#
# Epoch 00053: val_loss did not improve from 0.00115
# Epoch 54/100
# 129280/129280 [==============================] - 221s 2ms/step - loss: 9.2210e-04 - val_loss: 0.0012
#
# Epoch 00054: val_loss did not improve from 0.00115
# Epoch 55/100
# 129280/129280 [==============================] - 220s 2ms/step - loss: 9.1967e-04 - val_loss: 0.0012
#
# Epoch 00055: val_loss did not improve from 0.00115
# Epoch 56/100
# 129280/129280 [==============================] - 220s 2ms/step - loss: 9.1726e-04 - val_loss: 0.0012
#
# Epoch 00056: val_loss did not improve from 0.00115
# Epoch 57/100
# 129280/129280 [==============================] - 220s 2ms/step - loss: 9.2562e-04 - val_loss: 0.0012
#
# Epoch 00057: ReduceLROnPlateau reducing learning rate to 0.003486784128472209.
#
# Epoch 00057: val_loss did not improve from 0.00115
# Epoch 58/100
# 129280/129280 [==============================] - 221s 2ms/step - loss: 9.1742e-04 - val_loss: 0.0012
#
# Epoch 00058: val_loss did not improve from 0.00115
# Epoch 59/100
# 129280/129280 [==============================] - 220s 2ms/step - loss: 9.1410e-04 - val_loss: 0.0012
#
# Epoch 00059: val_loss did not improve from 0.00115
# Epoch 60/100
# 129280/129280 [==============================] - 220s 2ms/step - loss: 9.1561e-04 - val_loss: 0.0012
#
# Epoch 00060: val_loss did not improve from 0.00115
# Epoch 61/100
# 129280/129280 [==============================] - 220s 2ms/step - loss: 9.1099e-04 - val_loss: 0.0012
#
# Epoch 00061: val_loss did not improve from 0.00115
# Epoch 62/100
# 129280/129280 [==============================] - 220s 2ms/step - loss: 9.1693e-04 - val_loss: 0.0012
#
# Epoch 00062: ReduceLROnPlateau reducing learning rate to 0.003138105757534504.
#
# Epoch 00062: val_loss did not improve from 0.00115
# Epoch 63/100
# 129280/129280 [==============================] - 221s 2ms/step - loss: 9.1662e-04 - val_loss: 0.0012
#
# Epoch 00063: val_loss did not improve from 0.00115
# Epoch 64/100
# 129280/129280 [==============================] - 221s 2ms/step - loss: 9.0501e-04 - val_loss: 0.0012
#
# Epoch 00064: val_loss did not improve from 0.00115
# Epoch 65/100
# 129280/129280 [==============================] - 220s 2ms/step - loss: 9.0716e-04 - val_loss: 0.0012
#
# Epoch 00065: val_loss did not improve from 0.00115
# Epoch 66/100
# 129280/129280 [==============================] - 221s 2ms/step - loss: 9.0247e-04 - val_loss: 0.0012
#
# Epoch 00066: val_loss did not improve from 0.00115
# Epoch 67/100
# 129280/129280 [==============================] - 221s 2ms/step - loss: 9.0695e-04 - val_loss: 0.0012
#
# Epoch 00067: ReduceLROnPlateau reducing learning rate to 0.0028242952656000854.
#
# Epoch 00067: val_loss did not improve from 0.00115
# Epoch 68/100
# 129280/129280 [==============================] - 220s 2ms/step - loss: 8.9779e-04 - val_loss: 0.0012
#
# Epoch 00068: val_loss did not improve from 0.00115
# Epoch 69/100
# 129280/129280 [==============================] - 220s 2ms/step - loss: 8.9414e-04 - val_loss: 0.0012
#
# Epoch 00069: val_loss did not improve from 0.00115
# Epoch 70/100
# 129280/129280 [==============================] - 220s 2ms/step - loss: 8.9780e-04 - val_loss: 0.0012
#
# Epoch 00070: val_loss did not improve from 0.00115
# Epoch 71/100
# 129280/129280 [==============================] - 221s 2ms/step - loss: 8.9695e-04 - val_loss: 0.0012
#
# Epoch 00071: val_loss did not improve from 0.00115
# Epoch 72/100
# 129280/129280 [==============================] - 220s 2ms/step - loss: 8.9088e-04 - val_loss: 0.0012
#
# Epoch 00072: ReduceLROnPlateau reducing learning rate to 0.0025418657809495927.
#
# Epoch 00072: val_loss did not improve from 0.00115
# Epoch 73/100
# 129280/129280 [==============================] - 220s 2ms/step - loss: 8.9540e-04 - val_loss: 0.0012
#
# Epoch 00073: val_loss did not improve from 0.00115
# Epoch 74/100
# 129280/129280 [==============================] - 220s 2ms/step - loss: 8.9337e-04 - val_loss: 0.0012
#
# Epoch 00074: val_loss did not improve from 0.00115
# Epoch 75/100
# 129280/129280 [==============================] - 220s 2ms/step - loss: 8.9111e-04 - val_loss: 0.0012
#
# Epoch 00075: val_loss did not improve from 0.00115
# Epoch 76/100
# 129280/129280 [==============================] - 220s 2ms/step - loss: 8.8818e-04 - val_loss: 0.0012
#
# Epoch 00076: val_loss did not improve from 0.00115
# Epoch 77/100
# 129280/129280 [==============================] - 220s 2ms/step - loss: 8.8650e-04 - val_loss: 0.0012
#
# Epoch 00077: ReduceLROnPlateau reducing learning rate to 0.0022876791190356016.
#
# Epoch 00077: val_loss did not improve from 0.00115
# Epoch 78/100
# 129280/129280 [==============================] - 221s 2ms/step - loss: 8.8274e-04 - val_loss: 0.0012
#
# Epoch 00078: val_loss did not improve from 0.00115
# Epoch 79/100
# 129280/129280 [==============================] - 221s 2ms/step - loss: 8.8452e-04 - val_loss: 0.0012
#
# Epoch 00079: val_loss did not improve from 0.00115
# Epoch 80/100
# 129280/129280 [==============================] - 220s 2ms/step - loss: 8.8387e-04 - val_loss: 0.0012
#
# Epoch 00080: val_loss did not improve from 0.00115
# Epoch 81/100
# 129280/129280 [==============================] - 220s 2ms/step - loss: 8.7930e-04 - val_loss: 0.0012
#
# Epoch 00081: val_loss did not improve from 0.00115
# Epoch 82/100
# 129280/129280 [==============================] - 220s 2ms/step - loss: 8.8044e-04 - val_loss: 0.0012
#
# Epoch 00082: ReduceLROnPlateau reducing learning rate to 0.0020589112071320416.
#
# Epoch 00082: val_loss did not improve from 0.00115
# Epoch 83/100
# 129280/129280 [==============================] - 220s 2ms/step - loss: 8.7643e-04 - val_loss: 0.0012
#
# Epoch 00083: val_loss did not improve from 0.00115
# Epoch 84/100
# 129280/129280 [==============================] - 220s 2ms/step - loss: 8.7547e-04 - val_loss: 0.0012
#
# Epoch 00084: val_loss did not improve from 0.00115
# Epoch 85/100
# 129280/129280 [==============================] - 220s 2ms/step - loss: 8.7605e-04 - val_loss: 0.0012
#
# Epoch 00085: val_loss did not improve from 0.00115
# Epoch 86/100
# 129280/129280 [==============================] - 220s 2ms/step - loss: 8.7162e-04 - val_loss: 0.0012
#
# Epoch 00086: val_loss did not improve from 0.00115
# Epoch 87/100
# 129280/129280 [==============================] - 220s 2ms/step - loss: 8.6985e-04 - val_loss: 0.0012
#
# Epoch 00087: ReduceLROnPlateau reducing learning rate to 0.0018530200235545636.
#
# Epoch 00087: val_loss did not improve from 0.00115
# Epoch 88/100
# 129280/129280 [==============================] - 220s 2ms/step - loss: 8.7470e-04 - val_loss: 0.0012
#
# Epoch 00088: val_loss did not improve from 0.00115
# Epoch 89/100
# 129280/129280 [==============================] - 220s 2ms/step - loss: 8.7392e-04 - val_loss: 0.0012
#
# Epoch 00089: val_loss did not improve from 0.00115
# Epoch 90/100
# 129280/129280 [==============================] - 220s 2ms/step - loss: 8.7576e-04 - val_loss: 0.0012
#
# Epoch 00090: val_loss did not improve from 0.00115
# Epoch 91/100
# 129280/129280 [==============================] - 220s 2ms/step - loss: 8.6839e-04 - val_loss: 0.0012
#
# Epoch 00091: val_loss did not improve from 0.00115
# Epoch 92/100
# 129280/129280 [==============================] - 220s 2ms/step - loss: 8.7089e-04 - val_loss: 0.0012
#
# Epoch 00092: ReduceLROnPlateau reducing learning rate to 0.0016677180421538651.
#
# Epoch 00092: val_loss did not improve from 0.00115
# Epoch 93/100
# 129280/129280 [==============================] - 220s 2ms/step - loss: 8.6841e-04 - val_loss: 0.0012
#
# Epoch 00093: val_loss did not improve from 0.00115
# Epoch 94/100
# 129280/129280 [==============================] - 221s 2ms/step - loss: 8.6298e-04 - val_loss: 0.0012
#
# Epoch 00094: val_loss did not improve from 0.00115
# Epoch 95/100
# 129280/129280 [==============================] - 220s 2ms/step - loss: 8.6402e-04 - val_loss: 0.0012
#
# Epoch 00095: val_loss did not improve from 0.00115
# Epoch 96/100
# 129280/129280 [==============================] - 220s 2ms/step - loss: 8.6486e-04 - val_loss: 0.0012
#
# Epoch 00096: val_loss did not improve from 0.00115
# Epoch 97/100
# 129280/129280 [==============================] - 221s 2ms/step - loss: 8.6584e-04 - val_loss: 0.0012
#
# Epoch 00097: ReduceLROnPlateau reducing learning rate to 0.0015009462484158575.
#
# Epoch 00097: val_loss did not improve from 0.00115
# Epoch 98/100
# 129280/129280 [==============================] - 221s 2ms/step - loss: 8.6630e-04 - val_loss: 0.0012
#
# Epoch 00098: val_loss did not improve from 0.00115
# Epoch 99/100
# 129280/129280 [==============================] - 220s 2ms/step - loss: 8.7529e-04 - val_loss: 0.0012
#
# Epoch 00099: val_loss did not improve from 0.00115
# Epoch 100/100
# 129280/129280 [==============================] - 221s 2ms/step - loss: 8.6492e-04 - val_loss: 0.0011
#
# Epoch 00100: val_loss improved from 0.00115 to 0.00114, saving model to F:\Repository\temp\checkpoint\2018_08_08_weights_adam_256_50.hdf5
#
#
#  End of learning with

# %%
print('Training duration (s) : ', (time.time() - train_start_time)/60,'minutes')
# Out:
# Training duration (s) :  372.3384598692258 minutes

# %% [markdown]
# #### Plot of training history

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'val_loss', 'lr'])

# %%
plt.close()

# %%
plt.figure(figsize=(15,10)) 


#plt.ylim(0.001)
plt.plot(history.history['loss']) 
plt.plot(history.history['val_loss']) 
plt.title('model loss') 
plt.ylabel('loss') 
plt.xlabel('epoch') 
plt.legend(['loss', 'val_loss'], loc='best')

# %% [markdown]
# # Prediction Net
# #### Create new model for online learning

# %%
new_model = build_model(layers=layer_arch, batch_size = 1, predict = True)
#prediction_array[optimizer_unit] = predict_point_by_point(new_model, X_test)
# Out:
# > Compilation Time :  0.01396632194519043

# %%
new_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_7 (LSTM)                (1, 50, 50)               10400
# _________________________________________________________________
# lstm_8 (LSTM)                (1, 50, 100)              60400
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (1, 50, 100)              0
# _________________________________________________________________
# lstm_9 (LSTM)                (1, 50)                   30200
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (1, 50)                   0
# _________________________________________________________________
# dense_3 (Dense)              (1, 1)                    51
# _________________________________________________________________
# activation_3 (Activation)    (1, 1)                    0
# =================================================================
# Total params: 101,051
# Trainable params: 101,051
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Load the best model weights

# %%
new_model.load_weights('./checkpoint/' + date_stamp + "_weights_adam_"+ str(batch_size)+ '_' 
                             + str(seq_len)+ ".hdf5")

# %%
prediction_array = predict_point_by_point(new_model, X_test)

# %%
plt.close()

# %% [markdown]
# ### Plotting
# plot predictions together

# %%
window_size = 400

# %%
print("\n========== Prediction plot for limited Time units")
plt.close()
plt.figure(figsize=(15,10))
plt.plot(y_test[:window_size])

plt.plot(prediction_array[:400]) 
plt.title('model prediction') 
plt.ylabel('values') 
plt.xlabel('time unit') 
plt.legend(['actual_value', 'predicted_value'], loc='best')
plt.plot();
plt.pause(0.05)
# Out:
# ========== Prediction plot for limited Time units

# %%
# print("\n========== Prediction plot for limited Time units")
# plt.close()
# plt.figure(figsize=(15,10))
# plt.plot(y_test[:window_size])

# plt.plot(prediction_array[:400]) 
# plt.title('model prediction') 
# plt.ylabel('values') 
# plt.xlabel('time unit') 
# plt.legend(['actual_value', 'predicted_value'], loc='best')
# plt.plot();
# plt.pause(0.05)
# Out:
# ========== Prediction plot for limited Time units

# %% [markdown]
# #### RMSE

# %%
y_test.shape
# Out:
# (14389, 1)

# %%
y_test_reshaped = np.reshape(y_test,(y_test.shape[0],))

print("\nRMSE:")
print(np.sqrt(metrics.mean_squared_error(y_test_reshaped, prediction_array)))
print("\nMAE:")
print(metrics.mean_absolute_error(y_test_reshaped, prediction_array))

print("=======================")
# Out:
# RMSE:
# 0.03394384421846832
#
# MAE:
# 0.02198134335702457
# =======================
